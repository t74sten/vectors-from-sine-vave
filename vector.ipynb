# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
df = pd.read_excel('vector1.xlsx')
#df = df.dropna()
df
# Out:
#           t  1-1[A]  1-2[A]  2-1[A]  2-2[A]  3-1[A]  3-2[A]     phi_a1  \
# 0    0.0000   -9.00  410.75 -410.25     -10    -360     375   0.000000
# 1    0.0002   20.75  395.00 -434.00     -40    -345     395   0.062832
# 2    0.0004   62.00  374.50 -445.50     -85    -330     415   0.125664
# 3    0.0006   95.00  349.25 -459.25    -110    -305     425   0.188496
# 4    0.0008  131.00  333.50 -460.75    -135    -280     430   0.251327
# ..      ...     ...     ...     ...     ...     ...     ...        ...
# 924  0.1848  476.25 -225.25 -261.75    -495     275     230  58.056632
# 925  0.1850  476.75 -239.25 -239.25    -490     305     195  58.119464
# 926  0.1852  466.75 -264.50 -216.00    -485     320     170  58.182296
# 927  0.1854  468.25 -281.00 -194.25    -490     340     150  58.245128
# 928  0.1856  461.50 -315.25 -162.00    -475     365     115  58.307960
#
#            r_a1     phi_b1  ...        r_c1    phi_a2        r_a2    phi_b2  \
# ...

# %%
len(df.phi_a1)
# Out:
# 929

# %%
a1 = []
for i in df['1-1[A]'].values:
    a1.append(i)

# %%
xa1 = []
ya1 = []
for i in df.phi_a1:
    xa1.append(i)
for i in df.A:
    ya1.append(i)

xb1 = []
yb1 = []
for i in df.phi_b1:
    xb1.append(i)
for i in df.A:
    yb1.append(i)

xc1 = []
yc1 = []
for i in df.phi_c1:
    xc1.append(i)
for i in df.A:
    yc1.append(i)

# %%
xa2 = []
ya2 = []
for i in df.phi_a2:
    xa2.append(i)
for i in df.A:
    ya2.append(i)

xb2 = []
yb2 = []
for i in df.phi_b2:
    xb2.append(i)
for i in df.A:
    yb2.append(i)

xc2 = []
yc2 = []
for i in df.phi_c2:
    xc2.append(i)
for i in df.A:
    yc2.append(i)

# %%
fig = plt.figure(figsize=(18, 12))
ax = fig.add_subplot(121, projection="polar")
#ax1 = fig.add_subplot(122, projection="polar")

for i in list(range(0,10)):
    ax.plot((xa1[i], 0),(ya1[i], 0), 'yellow')
    ax.plot((xb1[i]+ 3.1415, 0),(yb1[i], 0), 'green')
    ax.plot((xc1[i]+ 3.1415, 0),(yc1[i], 0), 'red')

#for i in list(range(0,10)):
    #ax1.plot((xa2[i], 0),(ya2[i], 0), 'orange')
    #ax1.plot((xb2[i] + 3.1415, 0),(yb2[i], 0), 'blue')
    #ax1.plot((xc2[i] - 3.1415, 0),(yc2[i], 0), 'black')

plt.show()
